# %% [markdown]
# # MySQL
#
# Sebelum memulai, pastikan sudah :
# - Install Laragon
# - Start All pada Laragon
# - Install PyMySQL dengan cara: conda install pymysql
# - Import database mysqlsampledatabase.sql pada HeidiSQL melalui Tombol Database pada Laragon

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ## Berikut adalah Skema Database dari Sample Database yang telah kita Import dengan nama database Classicmodels:
#
# <img src="http://www.mysqltutorial.org/wp-content/uploads/2009/12/MySQL-Sample-Database-Schema.png" />

# %%
run("SHOW TABLES")

# %% [markdown]
# ## 1. Mengambil dan Memilih data dengan SELECT

# %%
run("SELECT * FROM products")

# %%
run("SELECT productName,buyPrice FROM products")

# %%
run("SELECT firstName,lastName FROM employees")

# %%
run("SELECT CONCAT(firstName,' ',lastName) AS fullName FROM employees")

# %%
run("SELECT * FROM orders")

# %%
run("SELECT orderNumber,YEAR(orderDate),MONTH(orderDate),DAY(orderDate) FROM orders")

# %%
# DISTINCT : Lihat Perbedaan dari Query dibawah ini
# run("SELECT lastName FROM employees")
run("SELECT DISTINCT lastName FROM employees")
# Out:
#      lastName
# 0      Murphy
# 1   Patterson
# 2    Firrelli
# 3      Bondur
# 4         Bow
# 5    Jennings
# 6    Thompson
# 7       Tseng
# 8      Vanauf
# 9   Hernandez
# 10   Castillo
# 11       Bott
# 12      Jones
# 13     Fixter
# 14      Marsh
# 15       King
# 16      Nishi
# 17       Kato
# 18     Gerard

# %% [markdown]
# ## 2. Kondisi dengan WHERE

# %%
run("SELECT productName,buyPrice FROM products WHERE buyPrice>90")
# Out:
#                             productName  buyPrice
# 0              1952 Alpine Renault 1300     98.58
# 1  2003 Harley-Davidson Eagle Drag Bike     91.02
# 2                1962 LanciaA Delta 16V    103.42
# 3                     1968 Ford Mustang     95.34
# 4                     2001 Ferrari Enzo     95.59
# 5                      1995 Honda Civic     93.89
# 6        1998 Chrysler Plymouth Prowler    101.51
# 7                 1970 Triumph Spitfire     91.92
# 8               1956 Porsche 356A Coupe     98.30

# %%
run("SELECT productName,buyPrice FROM products WHERE buyPrice BETWEEN 50 AND 60")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle='Sales Rep'")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle IN ('Sales Rep','VP Sales')")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle<>'Sales Rep'")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle='Sales Rep' AND officeCode=1")

# %%
run("""
SELECT firstName,lastName,jobTitle,officeCode 
FROM employees 
WHERE jobTitle='Sales Rep' AND officeCode=1 AND lastName='Thompson'
""")

# %%
run("""
SELECT   customername,
         country,
         state,
         creditlimit
FROM customers
WHERE country = 'USA'
        AND state = 'CA'
        AND creditlimit > 100000
""")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle<>'Sales Rep' OR officeCode=1")

# %%
run("""
SELECT 
    customername, country
FROM
    customers
WHERE
    country = 'USA' OR country = 'France'
""")

# %% [markdown]
# ## 3. Mengurutkan Hasil dengan Order By

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY buyPrice")

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY buyPrice DESC")
# Out:
#                                     productName       productLine  buyPrice
# 0                        1962 LanciaA Delta 16V      Classic Cars    103.42
# 1                1998 Chrysler Plymouth Prowler      Classic Cars    101.51
# 2                      1952 Alpine Renault 1300      Classic Cars     98.58
# 3                       1956 Porsche 356A Coupe      Classic Cars     98.30
# 4                             2001 Ferrari Enzo      Classic Cars     95.59
# 5                             1968 Ford Mustang      Classic Cars     95.34
# 6                              1995 Honda Civic      Classic Cars     93.89
# 7                         1970 Triumph Spitfire      Classic Cars     91.92
# 8          2003 Harley-Davidson Eagle Drag Bike       Motorcycles     91.02
# 9                            1969 Corvair Monza      Classic Cars     89.14
# 10                     1917 Grand Touring Sedan      Vintage Cars     86.70
# 11                          1972 Alfa Romeo GTA      Classic Cars     85.68
# 12                             1940s Ford truck  Trucks and Buses     84.76
# 13                              1993 Mazda RX-7      Classic Cars     83.51
# 14                             1969 Ford Falcon      Classic Cars     83.05
# 15                        18th century schooner             Ships     82.34
# 16                  1992 Ferrari 360 Spider red      Classic Cars     77.90
# 17                               1958 Setra Bus  Trucks and Buses     77.90
# 18                  1980s Black Hawk Helicopter            Planes     77.27
# 19                           1968 Dodge Charger      Classic Cars     75.16
# 20                       1964 Mercedes Tour Bus  Trucks and Buses     74.86
# 21                        1976 Ford Gran Torino      Classic Cars     73.49
# 22                            1952 Citroen-15CV      Classic Cars     72.82
# 23                       1928 Mercedes-Benz SSK      Vintage Cars     72.56
# 24                    1957 Corvette Convertible      Classic Cars     69.93
# 25            1992 Porsche Cayenne Turbo Silver      Classic Cars     69.78
# 26                        1996 Moto Guzzi 1100i       Motorcycles     68.99
# 27               America West Airlines B757-200            Planes     68.80
# 28                            1903 Ford Model A      Vintage Cars     68.30
# 29             Diamond T620 Semi-Skirted Tanker  Trucks and Buses     68.29
# ..                                          ...               ...       ...
# 64                               P-51-D Mustang            Planes     49.00
# 65        1969 Harley Davidson Ultimate Chopper       Motorcycles     48.81
# 66                     1940 Ford Delivery Sedan      Vintage Cars     48.64
# 67                           1949 Jaguar XK 120      Classic Cars     47.25
# 68                      1982 Ducati 900 Monster       Motorcycles     47.10
# 69             1912 Ford Model T Delivery Wagon      Vintage Cars     46.91
# 70                              1982 Camaro Z28      Classic Cars     46.53
# 71                                The Mayflower             Ships     43.30
# 72          1932 Alfa Romeo 8C2300 Spider Sport      Vintage Cars     43.26
# 73                                   HMS Bounty             Ships     39.83
# 74                    1971 Alpine Renault 1600s      Classic Cars     38.58
# 75               1962 City of Detroit Streetcar            Trains     37.49
# 76                     1960 BSA Gold Star DBD34       Motorcycles     37.32
# 77                    American Airlines: MD-11S            Planes     36.27
# 78                      1900s Vintage Tri-Plane            Planes     36.23
# 79                           1934 Ford V8 Coupe      Vintage Cars     34.35
# 80                       1900s Vintage Bi-Plane            Planes     34.25
# 81                        1957 Ford Thunderbird      Classic Cars     34.21
# 82                           2002 Yamaha YZR M1       Motorcycles     34.17
# 83                        The Schooner Bluenose             Ships     34.00
# 84                    The USS Constitution Ship             Ships     33.97
# 85  1996 Peterbilt 379 Stake Bed with Outrigger  Trucks and Buses     33.61
# 86                                   Pont Yacht             Ships     33.30
# 87                           1911 Ford Town Car      Vintage Cars     33.30
# 88                     1928 Ford Phaeton Deluxe      Vintage Cars     33.02
# 89                             1957 Vespa GS150       Motorcycles     32.95
# 90                             Boeing X-32A JSF            Planes     32.77
# 91                           1970 Dodge Coronet      Classic Cars     32.37
# 92                        1961 Chevrolet Impala      Classic Cars     32.33
# 93                      1970 Plymouth Hemi Cuda      Classic Cars     31.92
#
# [94 rows x 3 columns]

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice")

# %% [markdown]
# ## 4. Membatasi Hasil Dengan Limit

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice LIMIT 0,10")

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice LIMIT 20,10")

# %% [markdown]
# ## 5. Pencarian String

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    firstName LIKE 'a%'
""")

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    lastName LIKE '%on'
""")

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    lastname LIKE '%on%'
""")

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    lastname LIKE 'K_g'
""")

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    lastName NOT LIKE 'B%'
""")

# %%
run("""
SELECT 
    productCode, 
    productName
FROM
    products
WHERE
    productCode LIKE '%\_20%';
""")

# %% [markdown]
# Jika membutuhkan Pencarian yang lebih advanced dapat menggunakan BOOLEAN Text Search atau NATURAL LANGUAGE Search:
# - http://www.mysqltutorial.org/mysql-boolean-text-searches.aspx
# - http://www.mysqltutorial.org/mysql-natural-language-search.aspx

# %% [markdown]
# ## 6. Query Agregasi
# SUM, COUNT, AVG, MIN, MAX + GROUP BY + HAVING

# %%
run("SELECT avg(buyPrice) AS RataHarga FROM products where productline='classic cars'")

# %%
run("SELECT productLine,AVG(buyPrice) AS RataHarga FROM products GROUP BY productLine")

# %%
run("SELECT productLine,AVG(buyPrice) AS RataHarga FROM products GROUP BY productLine HAVING RataHarga>50")

# %%
run("SELECT productLine,MIN(buyPrice) AS HargaTermurah FROM products GROUP BY productLine")
# Out:
#         productLine  HargaTermurah
# 0      Classic Cars          15.91
# 1       Motorcycles          24.14
# 2            Planes          29.34
# 3             Ships          33.30
# 4            Trains          26.72
# 5  Trucks and Buses          24.92
# 6      Vintage Cars          20.61

# %%
run("SELECT productLine,MAX(buyPrice) AS HargaTermahal FROM products GROUP BY productLine")

# %%
run("SELECT productLine,COUNT(*) AS JumlahProduk FROM products GROUP BY productLine")
# Out:
#         productLine  JumlahProduk
# 0      Classic Cars            38
# 1       Motorcycles            13
# 2            Planes            12
# 3             Ships             9
# 4            Trains             3
# 5  Trucks and Buses            11
# 6      Vintage Cars            24

# %%
run("SELECT YEAR(paymentDate) AS Tahun,SUM(amount) AS TotalBayar FROM payments GROUP BY YEAR(paymentDate)")
# Out:
#    Tahun  TotalBayar
# 0   2003  3250217.70
# 1   2004  4313328.25
# 2   2005  1290293.28

# %%
run("""
SELECT 
    YEAR(paymentDate) AS Tahun,
    MONTH(paymentDate) AS Bulan,
    SUM(amount) AS TotalBayar 
FROM payments 
GROUP BY Tahun,Bulan
""")

# %%
run("""
SELECT 
    YEAR(paymentDate) AS Tahun,
    MONTH(paymentDate) AS Bulan,
    SUM(amount) AS TotalBayar 
FROM payments 
WHERE YEAR(paymentDate)<2005
GROUP BY Tahun,Bulan
HAVING TotalBayar > 300000
ORDER BY TotalBayar DESC
LIMIT 0,5
""")

# %% [markdown]
# ## SELF STUDY
# Materi Digital Talent untuk SQL hanya 3 pertemuan, sehingga hanya cukup untuk menyampaikan SELECT saja, namun kalian belum melihat bagaimana cara untuk membuat Tabel, Kolom, serta Bagaimana melakukan manipulasi Data, berikut materi tambahan untuk dapat memanipulasi data:
#
# - https://www.youtube.com/playlist?list=PLF82-I80PwDN7KSzsJOmd8mwHYe4aAqfF
#
# Playlist dari #1 hingga #10

# %% [markdown]
# ## LATIHAN
#
# Single entity
# 1. Prepare a list of offices sorted by country, state, city.
# 2. How many employees are there in the company?
# 3. What is the total of payments received?
# 4. List the product lines that contain 'Cars'.
# 5. Report total payments for October 28, 2004.
# 6. Report those payments greater than \$100,000.
# 7. List the products in each product line.
# 8. How many products in each product line?
# 9. What is the minimum payment received?
# 10. List all payments greater than twice the average payment.
# 11. What is the average percentage markup of the MSRP on buyPrice?
# 12. How many distinct products does ClassicModels sell?
# 13. Report the name and city of customers who don't have sales representatives?
# 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.
# 15. Which orders have a value greater than $5,000?

# %%
run("SELECT * FROM offices ORDER BY country,state,city") # 1
# Out:
#    TotalPayment
# 0    8853839.23

# %%
run("SELECT COUNT(*) As EmployeesCount FROM employees") # 2
# Out:
#    EmployeesCount
# 0              23

# %%
run("SELECT SUM(amount) AS TotalPayment FROM payments") # 3
# Out:
#    TotalPayment
# 0    8853839.23

# %%
run("""
SELECT DISTINCT
    productLine
FROM
    products
WHERE
    productLine LIKE '%cars%';
""") # 4
# Out:
#     productLine
# 0  Classic Cars
# 1  Vintage Cars

# %%
run("""
SELECT 
paymentDate, SUM(amount) as TotalPayment
FROM payments 
WHERE
paymentDate >= '2004-10-28'
AND
paymentDate <= '2004-10-29'
""") # 5
# Out:
#   paymentDate  TotalPayment
# 0  2004-10-28      47411.33

# %%
run("""
SELECT *
FROM payments 
WHERE amount > 100000
""") # 6
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %%
run("SELECT productName, productLine FROM products ORDER BY productLine") # 7
# Out:
#                                    productName       productLine
# 0                        1976 Ford Gran Torino      Classic Cars
# 1          1958 Chevy Corvette Limited Edition      Classic Cars
# 2                            1952 Citroen-15CV      Classic Cars
# 3                      1982 Lamborghini Diablo      Classic Cars
# 4                    1969 Chevrolet Camaro Z28      Classic Cars
# 5               1998 Chrysler Plymouth Prowler      Classic Cars
# 6                             1995 Honda Civic      Classic Cars
# 7                  1948 Porsche 356-A Roadster      Classic Cars
# 8                    1971 Alpine Renault 1600s      Classic Cars
# 9                           1949 Jaguar XK 120      Classic Cars
# 10                1999 Indy 500 Monte Carlo SS      Classic Cars
# 11                   1966 Shelby Cobra 427 S/C      Classic Cars
# 12                       1970 Triumph Spitfire      Classic Cars
# 13                        1969 Dodge Super Bee      Classic Cars
# 14                   1957 Corvette Convertible      Classic Cars
# 15                           1985 Toyota Supra      Classic Cars
# 16                 1992 Ferrari 360 Spider red      Classic Cars
# 17                       1957 Ford Thunderbird      Classic Cars
# 18                          1970 Dodge Coronet      Classic Cars
# 19              1948 Porsche Type 356 Roadster      Classic Cars
# 20                         2002 Chevy Corvette      Classic Cars
# 21                       1965 Aston Martin DB5      Classic Cars
# 22                     1970 Plymouth Hemi Cuda      Classic Cars
# 23                    1952 Alpine Renault 1300      Classic Cars
# 24                             1982 Camaro Z28      Classic Cars
# 25                         1972 Alfa Romeo GTA      Classic Cars
# 26                      1962 LanciaA Delta 16V      Classic Cars
# 27                           1968 Ford Mustang      Classic Cars
# 28                           2001 Ferrari Enzo      Classic Cars
# 29                          1969 Corvair Monza      Classic Cars
# ..                                         ...               ...
# 80                              1958 Setra Bus  Trucks and Buses
# 81                       1926 Ford Fire Engine  Trucks and Buses
# 82                      1964 Mercedes Tour Bus  Trucks and Buses
# 83                    1962 Volkswagen Microbus  Trucks and Buses
# 84                            1940s Ford truck  Trucks and Buses
# 85                           1957 Chevy Pickup  Trucks and Buses
# 86                         1904 Buick Runabout      Vintage Cars
# 87   1938 Cadillac V-16 Presidential Limousine      Vintage Cars
# 88                      1928 Mercedes-Benz SSK      Vintage Cars
# 89                    1917 Maxwell Touring Car      Vintage Cars
# 90                 1939 Chevrolet Deluxe Coupe      Vintage Cars
# 91                 1913 Ford Model T Speedster      Vintage Cars
# 92                          1934 Ford V8 Coupe      Vintage Cars
# 93         1932 Alfa Romeo 8C2300 Spider Sport      Vintage Cars
# 94         18th Century Vintage Horse Carriage      Vintage Cars
# 95                     1939 Cadillac Limousine      Vintage Cars
# 96                           1903 Ford Model A      Vintage Cars
# 97                       1936 Chrysler Airflow      Vintage Cars
# 98                        1937 Lincoln Berline      Vintage Cars
# 99            1936 Mercedes Benz 500k Roadster      Vintage Cars
# 100           1912 Ford Model T Delivery Wagon      Vintage Cars
# 101   1936 Mercedes-Benz 500K Special Roadster      Vintage Cars
# 102                   1940 Ford Delivery Sedan      Vintage Cars
# 103                  1937 Horch 930V Limousine      Vintage Cars
# 104                   1917 Grand Touring Sedan      Vintage Cars
# 105                   1928 Ford Phaeton Deluxe      Vintage Cars
# 106                         1911 Ford Town Car      Vintage Cars
# 107               1930 Buick Marquette Phaeton      Vintage Cars
# 108                  1932 Model A Ford J-Coupe      Vintage Cars
# 109    1941 Chevrolet Special Deluxe Cabriolet      Vintage Cars
#
# [110 rows x 2 columns]

# %%
run("SELECT productLine,COUNT(*) AS ProductAmount FROM products GROUP BY productLine") # 8
# Out:
#         productLine  ProductAmount
# 0      Classic Cars             38
# 1       Motorcycles             13
# 2            Planes             12
# 3             Ships              9
# 4            Trains              3
# 5  Trucks and Buses             11
# 6      Vintage Cars             24

# %%
run("SELECT * FROM payments WHERE amount = (SELECT MIN(amount) FROM payments)") # 9
# Out:
#    customerNumber checkNumber paymentDate  amount
# 0             398    JPMR4544  2005-05-18  615.45

# %%
run("SELECT * FROM payments WHERE amount > 2*(SELECT AVG(amount) FROM payments)") # 10
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %%
run("""
SELECT 
    AVG((MSRP - buyPrice) / buyPrice)
FROM 
    products
""") # 11
# Out:
#    AVG((MSRP - buyPrice) / buyPrice)
# 0                           0.887024

# %%
run("SELECT COUNT(DISTINCT productLine) FROM products") # 12
# Out:
#    COUNT(DISTINCT productLine)
# 0                            7

# %%
run("SELECT customerName, city FROM customers WHERE salesRepEmployeeNumber is Null") # 13
# Out:
#                       customerName              city
# 0               Havel & Zbyszek Co          Warszawa
# 1                Porto Imports Co.            Lisboa
# 2       Asian Shopping Network, Co         Singapore
# 3                  Natürlich Autos         Cunewalde
# 4                    ANG Resellers            Madrid
# 5         Messner Shopping Network         Frankfurt
# 6                Franken Gifts, Co           München
# 7                BG&E Collectables          Fribourg
# 8                 Schuyler Imports         Amsterdam
# 9                 Der Hund Imports            Berlin
# 10       Cramer Spezialitäten, Ltd       Brandenburg
# 11           Asian Treasures, Inc.              Cork
# 12            SAR Distributors, Co          Hatfield
# 13                 Kommission Auto           Münster
# 14          Lisboa Souveniers, Inc            Lisboa
# 15  Stuttgart Collectable Exchange         Stuttgart
# 16        Feuer Online Stores, Inc           Leipzig
# 17                Warburg Exchange            Aachen
# 18             Anton Designs, Ltd.            Madrid
# 19             Mit Vergnügen & Co.          Mannheim
# 20       Kremlin Collectables, Co.  Saint Petersburg
# 21              Raanan Stores, Inc           Herzlia

# %%
# run("ALTER TABLE employees ADD FULLTEXT(jobTitle)")
# run("""
# SELECT 
#     CONCAT(firstName,' ',lastName) AS fullName,
#     jobTitle 
# FROM 
#     employees 
# WHERE 
#     MATCH(FULLTEXT(jobTitle))
#     AGAINST('VP Manager' IN BOOLEAN MODE)""")
run("""
SELECT 
    CONCAT(firstName,' ',lastName) AS fullName,
    jobTitle 
FROM 
    employees 
WHERE 
    jobTitle LIKE 'VP%' or jobTitle LIKE '%manager%'""") #14
# Out:
#             fullName              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %%
run("""
SELECT 
    *
FROM 
    orders
WHERE 
    orderNumber IN
        (
        SELECT 
            orderNumber
        FROM 
            orderdetails
        WHERE
            (quantityOrdered * priceEach) > 5000
        )
""") # 15
# Out:
#      orderNumber   orderDate requiredDate shippedDate      status  \
# 0          10103  2003-01-29   2003-02-07  2003-02-02     Shipped
# 1          10105  2003-02-11   2003-02-21  2003-02-12     Shipped
# 2          10108  2003-03-03   2003-03-12  2003-03-08     Shipped
# 3          10109  2003-03-10   2003-03-19  2003-03-11     Shipped
# 4          10110  2003-03-18   2003-03-24  2003-03-20     Shipped
# 5          10112  2003-03-24   2003-04-03  2003-03-29     Shipped
# 6          10114  2003-04-01   2003-04-07  2003-04-02     Shipped
# 7          10115  2003-04-04   2003-04-12  2003-04-07     Shipped
# 8          10117  2003-04-16   2003-04-24  2003-04-17     Shipped
# 9          10119  2003-04-28   2003-05-05  2003-05-02     Shipped
# 10         10120  2003-04-29   2003-05-08  2003-05-01     Shipped
# 11         10121  2003-05-07   2003-05-13  2003-05-13     Shipped
# 12         10122  2003-05-08   2003-05-16  2003-05-13     Shipped
# 13         10123  2003-05-20   2003-05-29  2003-05-22     Shipped
# 14         10126  2003-05-28   2003-06-07  2003-06-02     Shipped
# 15         10127  2003-06-03   2003-06-09  2003-06-06     Shipped
# 16         10129  2003-06-12   2003-06-18  2003-06-14     Shipped
# 17         10134  2003-07-01   2003-07-10  2003-07-05     Shipped
# 18         10135  2003-07-02   2003-07-12  2003-07-03     Shipped
# 19         10136  2003-07-04   2003-07-14  2003-07-06     Shipped
# 20         10137  2003-07-10   2003-07-20  2003-07-14     Shipped
# 21         10139  2003-07-16   2003-07-23  2003-07-21     Shipped
# 22         10140  2003-07-24   2003-08-02  2003-07-30     Shipped
# 23         10141  2003-08-01   2003-08-09  2003-08-04     Shipped
# 24         10142  2003-08-08   2003-08-16  2003-08-13     Shipped
# 25         10143  2003-08-10   2003-08-18  2003-08-12     Shipped
# 26         10145  2003-08-25   2003-09-02  2003-08-31     Shipped
# 27         10147  2003-09-05   2003-09-12  2003-09-09     Shipped
# 28         10148  2003-09-11   2003-09-21  2003-09-15     Shipped
# 29         10149  2003-09-12   2003-09-18  2003-09-17     Shipped
# ..           ...         ...          ...         ...         ...
# 191        10379  2005-02-10   2005-02-18  2005-02-11     Shipped
# 192        10381  2005-02-17   2005-02-25  2005-02-18     Shipped
# 193        10382  2005-02-17   2005-02-23  2005-02-18     Shipped
# 194        10383  2005-02-22   2005-03-02  2005-02-25     Shipped
# 195        10388  2005-03-03   2005-03-11  2005-03-09     Shipped
# 196        10389  2005-03-03   2005-03-09  2005-03-08     Shipped
# 197        10390  2005-03-04   2005-03-11  2005-03-07     Shipped
# 198        10393  2005-03-11   2005-03-22  2005-03-14     Shipped
# 199        10395  2005-03-17   2005-03-24  2005-03-23     Shipped
# 200        10396  2005-03-23   2005-04-02  2005-03-28     Shipped
# 201        10399  2005-04-01   2005-04-12  2005-04-03     Shipped
# 202        10400  2005-04-01   2005-04-11  2005-04-04     Shipped
# 203        10401  2005-04-03   2005-04-14        None     On Hold
# 204        10402  2005-04-07   2005-04-14  2005-04-12     Shipped
# 205        10403  2005-04-08   2005-04-18  2005-04-11     Shipped
# 206        10404  2005-04-08   2005-04-14  2005-04-11     Shipped
# 207        10405  2005-04-14   2005-04-24  2005-04-20     Shipped
# 208        10406  2005-04-15   2005-04-25  2005-04-21    Disputed
# 209        10407  2005-04-22   2005-05-04        None     On Hold
# 210        10410  2005-04-29   2005-05-10  2005-04-30     Shipped
# 211        10412  2005-05-03   2005-05-13  2005-05-05     Shipped
# 212        10413  2005-05-05   2005-05-14  2005-05-09     Shipped
# 213        10414  2005-05-06   2005-05-13        None     On Hold
# 214        10417  2005-05-13   2005-05-19  2005-05-19    Disputed
# 215        10418  2005-05-16   2005-05-24  2005-05-20     Shipped
# 216        10419  2005-05-17   2005-05-28  2005-05-19     Shipped
# 217        10420  2005-05-29   2005-06-07        None  In Process
# 218        10421  2005-05-29   2005-06-06        None  In Process
# 219        10424  2005-05-31   2005-06-08        None  In Process
# 220        10425  2005-05-31   2005-06-07        None  In Process
#
#                                               comments  customerNumber
# 0                                                 None             121
# 1                                                 None             145
# 2                                                 None             385
# 3    Customer requested that FedEx Ground is used f...             486
# 4                                                 None             187
# 5    Customer requested that ad materials (such as ...             144
# 6                                                 None             172
# 7                                                 None             424
# 8                                                 None             148
# 9                                                 None             382
# 10                                                None             114
# 11                                                None             353
# 12                                                None             350
# 13                                                None             103
# 14                                                None             458
# 15   Customer requested special shippment. The inst...             151
# 16                                                None             324
# 17                                                None             250
# 18                                                None             124
# 19   Customer is interested in buying more Ferrari ...             242
# 20                                                None             353
# 21                                                None             282
# 22                                                None             161
# 23                                                None             334
# 24                                                None             124
# 25   Can we deliver the new Ford Mustang models by ...             320
# 26                                                None             205
# 27                                                None             379
# 28   They want to reevaluate their terms agreement ...             276
# 29                                                None             487
# ..                                                 ...             ...
# 191                                               None             141
# 192                                               None             321
# 193     Custom shipping instructions sent to warehouse             124
# 194                                               None             141
# 195                                               None             462
# 196                                               None             448
# 197  They want to reevaluate their terms agreement ...             124
# 198  They want to reevaluate their terms agreement ...             323
# 199  We must be cautions with this customer. Their ...             250
# 200                                               None             124
# 201                                               None             496
# 202  Customer requested that DHL is used for this s...             450
# 203  Customer credit limit exceeded. Will ship when...             328
# 204                                               None             406
# 205                                               None             201
# 206                                               None             323
# 207                                               None             209
# 208  Customer claims container with shipment was da...             145
# 209  Customer credit limit exceeded. Will ship when...             450
# 210                                               None             357
# 211                                               None             141
# 212  Customer requested that DHL is used for this s...             175
# 213  Customer credit limit exceeded. Will ship when...             362
# 214  Customer doesn't like the colors and precision...             141
# 215                                               None             412
# 216                                               None             382
# 217                                               None             282
# 218  Custom shipping instructions were sent to ware...             124
# 219                                               None             141
# 220                                               None             119
#
# [221 rows x 7 columns]
