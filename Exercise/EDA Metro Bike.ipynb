# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("metro-bike-share-trip-data.csv")
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Trip ID  Duration           Start Time             End Time  \
# 0  1912818       180  2016-07-07T04:17:00  2016-07-07T04:20:00
# 1  1919661      1980  2016-07-07T06:00:00  2016-07-07T06:33:00
# 2  1933383       300  2016-07-07T10:32:00  2016-07-07T10:37:00
# 3  1944197     10860  2016-07-07T10:37:00  2016-07-07T13:38:00
# 4  1940317       420  2016-07-07T12:51:00  2016-07-07T12:58:00
#
#    Starting Station ID  Starting Station Latitude  Starting Station Longitude  \
# 0               3014.0                  34.056610                  -118.23721
# 1               3014.0                  34.056610                  -118.23721
# 2               3016.0                  34.052898                  -118.24156
# 3               3016.0                  34.052898                  -118.24156
# 4               3032.0                  34.049889                  -118.25588
#
#    Ending Station ID  Ending Station Latitude  Ending Station Longitude  \
# 0             3014.0                34.056610                -118.23721
# 1             3014.0                34.056610                -118.23721
# 2             3016.0                34.052898                -118.24156
# 3             3016.0                34.052898                -118.24156
# 4             3032.0                34.049889                -118.25588
#
#    Bike ID  Plan Duration Trip Route Category Passholder Type  \
# 0   6281.0           30.0          Round Trip    Monthly Pass
# 1   6281.0           30.0          Round Trip    Monthly Pass
# 2   5861.0          365.0          Round Trip       Flex Pass
# 3   5861.0          365.0          Round Trip       Flex Pass
# 4   6674.0            0.0          Round Trip         Walk-up
#
#                                    Starting Lat-Long  \
# 0  {'longitude': '-118.23721', 'latitude': '34.05...
# 1  {'longitude': '-118.23721', 'latitude': '34.05...
# 2  {'longitude': '-118.24156', 'latitude': '34.05...
# 3  {'longitude': '-118.24156', 'latitude': '34.05...
# 4  {'longitude': '-118.25588', 'latitude': '34.04...
#
#                                      Ending Lat-Long
# 0  {'longitude': '-118.23721', 'latitude': '34.05...
# 1  {'longitude': '-118.23721', 'latitude': '34.05...
# 2  {'longitude': '-118.24156', 'latitude': '34.05...
# 3  {'longitude': '-118.24156', 'latitude': '34.05...
# 4  {'longitude': '-118.25588', 'latitude': '34.04...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132427 entries, 0 to 132426
# Data columns (total 16 columns):
# Trip ID                       132427 non-null int64
# Duration                      132427 non-null int64
# Start Time                    132427 non-null object
# End Time                      132427 non-null object
# Starting Station ID           132408 non-null float64
# Starting Station Latitude     132379 non-null float64
# Starting Station Longitude    132379 non-null float64
# Ending Station ID             132331 non-null float64
# Ending Station Latitude       131376 non-null float64
# Ending Station Longitude      131376 non-null float64
# Bike ID                       132417 non-null float64
# Plan Duration                 131661 non-null float64
# Trip Route Category           132427 non-null object
# Passholder Type               132427 non-null object
# Starting Lat-Long             98622 non-null object
# Ending Lat-Long               131376 non-null object
# dtypes: float64(8), int64(2), object(6)
# memory usage: 16.2+ MB

# %%
# Stratified Sampling function
def stratified_sampling(df, var, n_samples):
    data = df.groupby(var, group_keys=False).apply(lambda x: x.sample(min(len(x), n_samples)))
    return data

# %%
# See distribution of passenger type
print(df.groupby('Passholder Type')['Trip ID'].nunique())

# Because lowest variable comes from Staff Annual, we set the sampling by 300
# Sampling by passenger type
df_pass = stratified_sampling(df, 'Passholder Type', 300)
df_pass.head()
# Out:
# Passholder Type
# Flex Pass        9517
# Monthly Pass    81304
# Staff Annual      382
# Walk-up         41224
# Name: Trip ID, dtype: int64
#          Trip ID  Duration           Start Time             End Time  \
# 131172  23456885       360  2017-03-29T16:12:00  2017-03-29T16:18:00
# 9336     4681798      1260  2016-07-28T11:15:00  2016-07-28T11:36:00
# 10617    4726786       300  2016-07-30T15:58:00  2016-07-30T16:03:00
# 13237    4832168       660  2016-08-03T15:40:00  2016-08-03T15:51:00
# 9783     4706592       720  2016-07-29T07:26:00  2016-07-29T07:38:00
#
#         Starting Station ID  Starting Station Latitude  \
# 131172               3067.0                  34.045181
# 9336                 3047.0                  34.039982
# 10617                3046.0                  34.053021
# 13237                3062.0                  34.047749
# 9783                 3014.0                  34.056610
#
#         Starting Station Longitude  Ending Station ID  \
# 131172                 -118.250237             3064.0
# 9336                   -118.266400             3032.0
# 10617                  -118.247950             3069.0
# 13237                  -118.243170             3049.0
# 9783                   -118.237210             3063.0
#
#         Ending Station Latitude  Ending Station Longitude  Bike ID  \
# 131172                34.046810               -118.256981   6583.0
# 9336                  34.049889               -118.255880   5943.0
# 10617                 34.050880               -118.248250   6585.0
# 13237                 34.056969               -118.253590   6119.0
# 9783                  34.049198               -118.252830   6123.0
#
#         Plan Duration Trip Route Category Passholder Type  \
# 131172          365.0             One Way       Flex Pass
# 9336            365.0             One Way       Flex Pass
# 10617           365.0             One Way       Flex Pass
# 13237           365.0             One Way       Flex Pass
# 9783            365.0             One Way       Flex Pass
#
#                                         Starting Lat-Long  \
# 131172                                                NaN
# 9336    {'longitude': '-118.2664', 'latitude': '34.039...
# 10617   {'longitude': '-118.24795', 'latitude': '34.05...
# 13237   {'longitude': '-118.24317', 'latitude': '34.04...
# 9783    {'longitude': '-118.23721', 'latitude': '34.05...
#
#                                           Ending Lat-Long
# 131172  {'longitude': '-118.256981', 'latitude': '34.0...
# 9336    {'longitude': '-118.25588', 'latitude': '34.04...
# 10617   {'longitude': '-118.24825', 'latitude': '34.05...
# 13237   {'longitude': '-118.25359', 'latitude': '34.05...
# 9783    {'longitude': '-118.25283', 'latitude': '34.04...

# %%
# Count distance by kilometres
lon1, lat1, lon2, lat2 = map(np.radians, [df['Starting Station Longitude'], df['Starting Station Latitude'],df['Ending Station Longitude'], df['Ending Station Latitude']])
dlat = lat2 - lat1 
dlon = lon2 - lon1
a = (np.sin(dlat/2))**2 +np.cos(lat1) * np.cos(lat2) * (np.sin(dlon/2))**2 
c = 2 * np.arcsin( np.sqrt(a)) 
d = 6373  * c 
df_pass['distance in km']=d
df_pass['distance in km'].hist(bins=100,range=(0,5))

# Describe by group
